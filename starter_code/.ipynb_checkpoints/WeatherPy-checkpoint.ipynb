# %% [markdown]
# # WeatherPy
# ----
#
# #### Analysis
# * There is a slightly greater correlation in the Southern Hemisphere between Latitude and Maximum Temperature than the Northern Hemisphere
#
# * The correlation between Latitude and Maximum Temperature is positive below latitude 20 and negative above Latitud 20. The closer the city’s latitud is to latitud 20 the higher the Temperature
#
# * In general more cities tend to have humidity  above 40% in both hemispheres, also, the correlation between Latitud and Humidity is vey weak in both hemispheres
#
# * The correlation between Latitud and Cloudiness is vey weak in both hemispheres
#
# * In general in both hemispheres more cities have wind speeds below 6 mph, also, the correlation between Latitud and wind speed is vey weak in both hemispheres

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 591

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
params={"appid":weather_api_key}
base_url="http://api.openweathermap.org/data/2.5/weather?" 

#create a dataframe, column City contains cities list
weather_df=pd.DataFrame({"City":cities })

#create new empty columns in the dataframe
weather_df["Latitude"]=""
weather_df["Longitude"]=""
weather_df["Max Temp (F)"]=""
weather_df["Humidity (%)"]=""
weather_df["Cloudiness (%)"]=""
weather_df["Wind Speed (mph)"]=""
weather_df["Country"]=""
weather_df["Date"]=""

#iterate over everycity in Column City and obtain,
#Latitude, Longitude, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date from openweathermap for the corresponding city

for index, row in weather_df.iterrows():
    city=row["City"]
    params["q"]=city
    data=requests.get(base_url, params=params).json()
    print(f"--------------------------------------\n {cities.index(city)} {city}: the data is being retreived") 
    
    try:
        weather_df.loc[index,"Latitude"]=data["coord"]["lat"]
        weather_df.loc[index,"Longitude"]=data["coord"]["lon"]
        #change temperature in kelvin to fahrenheit
        kelvin=data["main"]["temp_max"]
        fahrenheit=((kelvin-273.15)*9/5)+32
        weather_df.loc[index,"Max Temp (F)"]=fahrenheit
        
        weather_df.loc[index,"Humidity (%)"]=data["main"]["humidity"]
        weather_df.loc[index,"Cloudiness (%)"]=data["clouds"]["all"]
        weather_df.loc[index,"Wind Speed (mph)"]=data["wind"]["speed"]
        weather_df.loc[index,"Country"]=data["sys"]["country"]
        
        timestamp=weather_df.loc[index,"Date"]
        datetime=time.strftime("%m/%d/%Y", ts)
        weather_df.loc[index,"Date"]=datetime

        
    except(KeyError, IndexError):
        print(f"Error missing city [{city}] in open weather api")
# Out:
# --------------------------------------
#  0 acapulco: the data is being retreived
# --------------------------------------
#  1 kurilsk: the data is being retreived
# --------------------------------------
#  2 sinnamary: the data is being retreived
# --------------------------------------
#  3 faanui: the data is being retreived
# --------------------------------------
#  4 leningradskiy: the data is being retreived
# --------------------------------------
#  5 lipno: the data is being retreived
# --------------------------------------
#  6 rikitea: the data is being retreived
# --------------------------------------
#  7 altamont: the data is being retreived
# --------------------------------------
#  8 jamestown: the data is being retreived
# --------------------------------------
#  9 farmington: the data is being retreived
# --------------------------------------
#  10 auxerre: the data is being retreived
# --------------------------------------
#  11 ucluelet: the data is being retreived
# --------------------------------------
#  12 bhubaneswar: the data is being retreived
# --------------------------------------
#  13 tawkar: the data is being retreived
# Error missing city [tawkar] in open weather api
# --------------------------------------
#  14 kalmunai: the data is being retreived
# --------------------------------------
#  15 sentyabrskiy: the data is being retreived
# Error missing city [sentyabrskiy] in open weather api
# --------------------------------------
#  16 bluff: the data is being retreived
# --------------------------------------
#  17 hithadhoo: the data is being retreived
# --------------------------------------
#  18 tuktoyaktuk: the data is being retreived
# --------------------------------------
#  19 airai: the data is being retreived
# --------------------------------------
#  20 saskylakh: the data is being retreived
# --------------------------------------
#  21 antofagasta: the data is being retreived
# --------------------------------------
#  22 provideniya: the data is being retreived
# --------------------------------------
#  23 saint-georges: the data is being retreived
# --------------------------------------
#  24 yellowknife: the data is being retreived
# --------------------------------------
#  25 tatarbunary: the data is being retreived
# --------------------------------------
#  26 east london: the data is being retreived
# --------------------------------------
#  27 havoysund: the data is being retreived
# --------------------------------------
#  28 odweyne: the data is being retreived
# --------------------------------------
#  29 vaini: the data is being retreived
# --------------------------------------
#  30 taolanaro: the data is being retreived
# Error missing city [taolanaro] in open weather api
# --------------------------------------
#  31 port elizabeth: the data is being retreived
# --------------------------------------
#  32 belyy yar: the data is being retreived
# --------------------------------------
#  33 fairbanks: the data is being retreived
# --------------------------------------
#  34 mataura: the data is being retreived
# --------------------------------------
#  35 kitui: the data is being retreived
# --------------------------------------
#  36 avarua: the data is being retreived
# --------------------------------------
#  37 gulshat: the data is being retreived
# Error missing city [gulshat] in open weather api
# --------------------------------------
#  38 hermanus: the data is being retreived
# --------------------------------------
#  39 pudozh: the data is being retreived
# --------------------------------------
#  40 hobart: the data is being retreived
# --------------------------------------
#  41 college: the data is being retreived
# --------------------------------------
#  42 kruisfontein: the data is being retreived
# --------------------------------------
#  43 arraial do cabo: the data is being retreived
# --------------------------------------
#  44 esperance: the data is being retreived
# --------------------------------------
#  45 hasaki: the data is being retreived
# --------------------------------------
#  46 mitsamiouli: the data is being retreived
# --------------------------------------
#  47 wagga wagga: the data is being retreived
# --------------------------------------
#  48 busselton: the data is being retreived
# --------------------------------------
#  49 albany: the data is being retreived
# --------------------------------------
#  50 ilulissat: the data is being retreived
# --------------------------------------
#  51 port hedland: the data is being retreived
# --------------------------------------
#  52 kapaa: the data is being retreived
# --------------------------------------
#  53 punta arenas: the data is being retreived
# --------------------------------------
#  54 tasiilaq: the data is being retreived
# --------------------------------------
#  55 kodiak: the data is being retreived
# --------------------------------------
#  56 pevek: the data is being retreived
# --------------------------------------
#  57 mocuba: the data is being retreived
# --------------------------------------
#  58 nikolskoye: the data is being retreived
# --------------------------------------
#  59 dwarka: the data is being retreived
# --------------------------------------
#  60 smithers: the data is being retreived
# --------------------------------------
#  61 whyalla: the data is being retreived
# --------------------------------------
#  62 roald: the data is being retreived
# --------------------------------------
#  63 puerto baquerizo moreno: the data is being retreived
# --------------------------------------
#  64 sao joao da barra: the data is being retreived
# --------------------------------------
#  65 souillac: the data is being retreived
# --------------------------------------
#  66 castro: the data is being retreived
# --------------------------------------
#  67 kyra: the data is being retreived
# --------------------------------------
#  68 bredasdorp: the data is being retreived
# --------------------------------------
#  69 ushuaia: the data is being retreived
# --------------------------------------
#  70 tuatapere: the data is being retreived
# --------------------------------------
#  71 iqaluit: the data is being retreived
# --------------------------------------
#  72 esna: the data is being retreived
# --------------------------------------
#  73 changji: the data is being retreived
# --------------------------------------
#  74 atuona: the data is being retreived
# --------------------------------------
#  75 leshukonskoye: the data is being retreived
# --------------------------------------
#  76 pathein: the data is being retreived
# --------------------------------------
#  77 tabiauea: the data is being retreived
# Error missing city [tabiauea] in open weather api
# --------------------------------------
#  78 hihifo: the data is being retreived
# Error missing city [hihifo] in open weather api
# --------------------------------------
#  79 port blair: the data is being retreived
# --------------------------------------
#  80 meyungs: the data is being retreived
# Error missing city [meyungs] in open weather api
# --------------------------------------
#  81 nanortalik: the data is being retreived
# --------------------------------------
#  82 shenzhen: the data is being retreived
# --------------------------------------
#  83 olinda: the data is being retreived
# --------------------------------------
#  84 kipini: the data is being retreived
# --------------------------------------
#  85 port lincoln: the data is being retreived
# --------------------------------------
#  86 gopalpur: the data is being retreived
# --------------------------------------
#  87 aswan: the data is being retreived
# --------------------------------------
#  88 tiksi: the data is being retreived
# --------------------------------------
#  89 cherskiy: the data is being retreived
# --------------------------------------
#  90 los llanos de aridane: the data is being retreived
# --------------------------------------
#  91 amderma: the data is being retreived
# Error missing city [amderma] in open weather api
# --------------------------------------
#  92 veracruz: the data is being retreived
# --------------------------------------
#  93 lompoc: the data is being retreived
# --------------------------------------
#  94 qiongshan: the data is being retreived
# --------------------------------------
#  95 barentsburg: the data is being retreived
# Error missing city [barentsburg] in open weather api
# --------------------------------------
#  96 kemi: the data is being retreived
# --------------------------------------
#  97 cape town: the data is being retreived
# --------------------------------------
#  98 vestbygda: the data is being retreived
# Error missing city [vestbygda] in open weather api
# --------------------------------------
#  99 tilichiki: the data is being retreived
# --------------------------------------
#  100 roma: the data is being retreived
# --------------------------------------
#  101 alofi: the data is being retreived
# --------------------------------------
#  102 bur gabo: the data is being retreived
# Error missing city [bur gabo] in open weather api
# --------------------------------------
#  103 sakakah: the data is being retreived
# --------------------------------------
#  104 illoqqortoormiut: the data is being retreived
# Error missing city [illoqqortoormiut] in open weather api
# --------------------------------------
#  105 kaitangata: the data is being retreived
# --------------------------------------
#  106 shubarshi: the data is being retreived
# --------------------------------------
#  107 mar del plata: the data is being retreived
# --------------------------------------
#  108 raton: the data is being retreived
# --------------------------------------
#  109 norman wells: the data is being retreived
# --------------------------------------
#  110 belmonte: the data is being retreived
# --------------------------------------
#  111 gargzdai: the data is being retreived
# --------------------------------------
#  112 san quintin: the data is being retreived
# --------------------------------------
#  113 sao paulo de olivenca: the data is being retreived
# --------------------------------------
#  114 tessalit: the data is being retreived
# --------------------------------------
#  115 cairns: the data is being retreived
# --------------------------------------
#  116 qaanaaq: the data is being retreived
# --------------------------------------
#  117 lasa: the data is being retreived
# --------------------------------------
#  118 bokspits: the data is being retreived
# Error missing city [bokspits] in open weather api
# --------------------------------------
#  119 marfino: the data is being retreived
# --------------------------------------
#  120 half moon bay: the data is being retreived
# --------------------------------------
#  121 koidu: the data is being retreived
# --------------------------------------
#  122 caravelas: the data is being retreived
# --------------------------------------
#  123 kargasok: the data is being retreived
# --------------------------------------
#  124 mahebourg: the data is being retreived
# --------------------------------------
#  125 mitu: the data is being retreived
# --------------------------------------
#  126 miedzyrzec podlaski: the data is being retreived
# --------------------------------------
#  127 shingu: the data is being retreived
# --------------------------------------
#  128 khatanga: the data is being retreived
# --------------------------------------
#  129 karamea: the data is being retreived
# Error missing city [karamea] in open weather api
# --------------------------------------
#  130 aklavik: the data is being retreived
# --------------------------------------
#  131 anadyr: the data is being retreived
# --------------------------------------
#  132 nangomba: the data is being retreived
# --------------------------------------
#  133 puerto ayora: the data is being retreived
# --------------------------------------
#  134 praya: the data is being retreived
# --------------------------------------
#  135 georgetown: the data is being retreived
# --------------------------------------
#  136 sorland: the data is being retreived
# --------------------------------------
#  137 moosomin: the data is being retreived
# --------------------------------------
#  138 saint-philippe: the data is being retreived
# --------------------------------------
#  139 kerteh: the data is being retreived
# Error missing city [kerteh] in open weather api
# --------------------------------------
#  140 olafsvik: the data is being retreived
# --------------------------------------
#  141 ulundi: the data is being retreived
# --------------------------------------
#  142 lebu: the data is being retreived
# --------------------------------------
#  143 constitucion: the data is being retreived
# --------------------------------------
#  144 ikot ekpene: the data is being retreived
# --------------------------------------
#  145 skalistyy: the data is being retreived
# Error missing city [skalistyy] in open weather api
# --------------------------------------
#  146 letterkenny: the data is being retreived
# --------------------------------------
#  147 luderitz: the data is being retreived
# --------------------------------------
#  148 dikson: the data is being retreived
# --------------------------------------
#  149 matara: the data is being retreived
# --------------------------------------
#  150 thompson: the data is being retreived
# --------------------------------------
#  151 bethel: the data is being retreived
# --------------------------------------
#  152 westport: the data is being retreived
# --------------------------------------
#  153 celestun: the data is being retreived
# --------------------------------------
#  154 komsomolskiy: the data is being retreived
# --------------------------------------
#  155 port alfred: the data is being retreived
# --------------------------------------
#  156 oussouye: the data is being retreived
# --------------------------------------
#  157 kaabong: the data is being retreived
# --------------------------------------
#  158 port-cartier: the data is being retreived
# --------------------------------------
#  159 cabo san lucas: the data is being retreived
# --------------------------------------
#  160 cidreira: the data is being retreived
# --------------------------------------
#  161 butaritari: the data is being retreived
# --------------------------------------
#  162 bambous virieux: the data is being retreived
# --------------------------------------
#  163 mogadishu: the data is being retreived
# --------------------------------------
#  164 saleaula: the data is being retreived
# Error missing city [saleaula] in open weather api
# --------------------------------------
#  165 hefei: the data is being retreived
# --------------------------------------
#  166 road town: the data is being retreived
# --------------------------------------
#  167 nizhniy odes: the data is being retreived
# --------------------------------------
#  168 xuddur: the data is being retreived
# --------------------------------------
#  169 naze: the data is being retreived
# --------------------------------------
#  170 nabire: the data is being retreived
# --------------------------------------
#  171 tautira: the data is being retreived
# --------------------------------------
#  172 marienburg: the data is being retreived
# --------------------------------------
#  173 macau: the data is being retreived
# --------------------------------------
#  174 dandong: the data is being retreived
# --------------------------------------
#  175 manjacaze: the data is being retreived
# --------------------------------------
#  176 yarmouth: the data is being retreived
# --------------------------------------
#  177 zhanatas: the data is being retreived
# Error missing city [zhanatas] in open weather api
# --------------------------------------
#  178 tromso: the data is being retreived
# --------------------------------------
#  179 kamenskoye: the data is being retreived
# Error missing city [kamenskoye] in open weather api
# --------------------------------------
#  180 robertson: the data is being retreived
# --------------------------------------
#  181 jackson: the data is being retreived
# --------------------------------------
#  182 noumea: the data is being retreived
# --------------------------------------
#  183 katsina: the data is being retreived
# --------------------------------------
#  184 carikar: the data is being retreived
# Error missing city [carikar] in open weather api
# --------------------------------------
#  185 ialibu: the data is being retreived
# --------------------------------------
#  186 kavieng: the data is being retreived
# --------------------------------------
#  187 grand river south east: the data is being retreived
# Error missing city [grand river south east] in open weather api
# --------------------------------------
#  188 chanute: the data is being retreived
# --------------------------------------
#  189 esmeraldas: the data is being retreived
# --------------------------------------
#  190 kharp: the data is being retreived
# --------------------------------------
#  191 hilo: the data is being retreived
# --------------------------------------
#  192 chingirlau: the data is being retreived
# --------------------------------------
#  193 barrow: the data is being retreived
# --------------------------------------
#  194 dolbeau: the data is being retreived
# Error missing city [dolbeau] in open weather api
# --------------------------------------
#  195 chokurdakh: the data is being retreived
# --------------------------------------
#  196 brownwood: the data is being retreived
# --------------------------------------
#  197 okato: the data is being retreived
# --------------------------------------
#  198 vila franca do campo: the data is being retreived
# --------------------------------------
#  199 veraval: the data is being retreived
# --------------------------------------
#  200 nemuro: the data is being retreived
# --------------------------------------
#  201 at-bashi: the data is being retreived
# --------------------------------------
#  202 bengkulu: the data is being retreived
# --------------------------------------
#  203 lisbon: the data is being retreived
# --------------------------------------
#  204 amapa: the data is being retreived
# --------------------------------------
#  205 sao filipe: the data is being retreived
# --------------------------------------
#  206 synya: the data is being retreived
# --------------------------------------
#  207 ouro preto do oeste: the data is being retreived
# --------------------------------------
#  208 bargal: the data is being retreived
# Error missing city [bargal] in open weather api
# --------------------------------------
#  209 attawapiskat: the data is being retreived
# Error missing city [attawapiskat] in open weather api
# --------------------------------------
#  210 kholodnyy: the data is being retreived
# --------------------------------------
#  211 unye: the data is being retreived
# Error missing city [unye] in open weather api
# --------------------------------------
#  212 portadown: the data is being retreived
# --------------------------------------
#  213 labuhan: the data is being retreived
# --------------------------------------
#  214 ambon: the data is being retreived
# --------------------------------------
#  215 batagay-alyta: the data is being retreived
# --------------------------------------
#  216 manaus: the data is being retreived
# --------------------------------------
#  217 birjand: the data is being retreived
# --------------------------------------
#  218 zhongxing: the data is being retreived
# --------------------------------------
#  219 tabat: the data is being retreived
# --------------------------------------
#  220 san patricio: the data is being retreived
# --------------------------------------
#  221 corsico: the data is being retreived
# --------------------------------------
#  222 yar-sale: the data is being retreived
# --------------------------------------
#  223 stornoway: the data is being retreived
# --------------------------------------
#  224 vardo: the data is being retreived
# --------------------------------------
#  225 senanga: the data is being retreived
# --------------------------------------
#  226 calvinia: the data is being retreived
# --------------------------------------
#  227 thinadhoo: the data is being retreived
# --------------------------------------
#  228 carnarvon: the data is being retreived
# --------------------------------------
#  229 torbay: the data is being retreived
# --------------------------------------
#  230 buqayq: the data is being retreived
# Error missing city [buqayq] in open weather api
# --------------------------------------
#  231 nur: the data is being retreived
# --------------------------------------
#  232 ponta do sol: the data is being retreived
# --------------------------------------
#  233 vostok: the data is being retreived
# --------------------------------------
#  234 the pas: the data is being retreived
# --------------------------------------
#  235 hualmay: the data is being retreived
# --------------------------------------
#  236 solwezi: the data is being retreived
# --------------------------------------
#  237 nizhneyansk: the data is being retreived
# Error missing city [nizhneyansk] in open weather api
# --------------------------------------
#  238 severo-kurilsk: the data is being retreived
# --------------------------------------
#  239 mount isa: the data is being retreived
# --------------------------------------
#  240 huambo: the data is being retreived
# --------------------------------------
#  241 salalah: the data is being retreived
# --------------------------------------
#  242 ancud: the data is being retreived
# --------------------------------------
#  243 djibo: the data is being retreived
# --------------------------------------
#  244 codrington: the data is being retreived
# --------------------------------------
#  245 dafeng: the data is being retreived
# --------------------------------------
#  246 nome: the data is being retreived
# --------------------------------------
#  247 talara: the data is being retreived
# --------------------------------------
#  248 belushya guba: the data is being retreived
# Error missing city [belushya guba] in open weather api
# --------------------------------------
#  249 ponta delgada: the data is being retreived
# --------------------------------------
#  250 bundaberg: the data is being retreived
# --------------------------------------
#  251 zalesovo: the data is being retreived
# --------------------------------------
#  252 nioki: the data is being retreived
# --------------------------------------
#  253 dzhusaly: the data is being retreived
# Error missing city [dzhusaly] in open weather api
# --------------------------------------
#  254 la ronge: the data is being retreived
# --------------------------------------
#  255 hrubieszow: the data is being retreived
# --------------------------------------
#  256 sheridan: the data is being retreived
# --------------------------------------
#  257 ribeira grande: the data is being retreived
# --------------------------------------
#  258 dingle: the data is being retreived
# --------------------------------------
#  259 kenai: the data is being retreived
# --------------------------------------
#  260 mrirt: the data is being retreived
# Error missing city [mrirt] in open weather api
# --------------------------------------
#  261 singaraja: the data is being retreived
# --------------------------------------
#  262 taltal: the data is being retreived
# --------------------------------------
#  263 asau: the data is being retreived
# --------------------------------------
#  264 san cristobal: the data is being retreived
# --------------------------------------
#  265 manavalakurichi: the data is being retreived
# --------------------------------------
#  266 kamenka: the data is being retreived
# --------------------------------------
#  267 scarborough: the data is being retreived
# --------------------------------------
#  268 dharangaon: the data is being retreived
# --------------------------------------
#  269 mys shmidta: the data is being retreived
# Error missing city [mys shmidta] in open weather api
# --------------------------------------
#  270 barinas: the data is being retreived
# --------------------------------------
#  271 deputatskiy: the data is being retreived
# --------------------------------------
#  272 turukhansk: the data is being retreived
# --------------------------------------
#  273 palaia fokaia: the data is being retreived
# --------------------------------------
#  274 ahipara: the data is being retreived
# --------------------------------------
#  275 yiyang: the data is being retreived
# --------------------------------------
#  276 krasnoselkup: the data is being retreived
# --------------------------------------
#  277 stokmarknes: the data is being retreived
# --------------------------------------
#  278 kamiiso: the data is being retreived
# --------------------------------------
#  279 berdigestyakh: the data is being retreived
# --------------------------------------
#  280 mikhaylovsk: the data is being retreived
# --------------------------------------
#  281 ossora: the data is being retreived
# --------------------------------------
#  282 hamilton: the data is being retreived
# --------------------------------------
#  283 malanje: the data is being retreived
# --------------------------------------
#  284 vila velha: the data is being retreived
# --------------------------------------
#  285 husavik: the data is being retreived
# --------------------------------------
#  286 kardla: the data is being retreived
# --------------------------------------
#  287 varkkallai: the data is being retreived
# --------------------------------------
#  288 katobu: the data is being retreived
# --------------------------------------
#  289 wulanhaote: the data is being retreived
# Error missing city [wulanhaote] in open weather api
# --------------------------------------
#  290 ayan: the data is being retreived
# --------------------------------------
#  291 rantauprapat: the data is being retreived
# --------------------------------------
#  292 bilma: the data is being retreived
# --------------------------------------
#  293 ponta pora: the data is being retreived
# --------------------------------------
#  294 geraldton: the data is being retreived
# --------------------------------------
#  295 jacmel: the data is being retreived
# --------------------------------------
#  296 itiuba: the data is being retreived
# --------------------------------------
#  297 torrevieja: the data is being retreived
# --------------------------------------
#  298 yilan: the data is being retreived
# --------------------------------------
#  299 qaqortoq: the data is being retreived
# --------------------------------------
#  300 tazovskiy: the data is being retreived
# --------------------------------------
#  301 vestmannaeyjar: the data is being retreived
# --------------------------------------
#  302 broome: the data is being retreived
# --------------------------------------
#  303 bull savanna: the data is being retreived
# --------------------------------------
#  304 alyangula: the data is being retreived
# --------------------------------------
#  305 ahuimanu: the data is being retreived
# --------------------------------------
#  306 buala: the data is being retreived
# --------------------------------------
#  307 northfield: the data is being retreived
# --------------------------------------
#  308 biltine: the data is being retreived
# --------------------------------------
#  309 takoradi: the data is being retreived
# --------------------------------------
#  310 pacific grove: the data is being retreived
# --------------------------------------
#  311 nacajuca: the data is being retreived
# --------------------------------------
#  312 jalu: the data is being retreived
# --------------------------------------
#  313 tias: the data is being retreived
# --------------------------------------
#  314 flin flon: the data is being retreived
# --------------------------------------
#  315 tigil: the data is being retreived
# --------------------------------------
#  316 sterling: the data is being retreived
# --------------------------------------
#  317 nurobod: the data is being retreived
# --------------------------------------
#  318 pogar: the data is being retreived
# --------------------------------------
#  319 omboue: the data is being retreived
# --------------------------------------
#  320 bonthe: the data is being retreived
# --------------------------------------
#  321 upernavik: the data is being retreived
# --------------------------------------
#  322 te anau: the data is being retreived
# --------------------------------------
#  323 haines junction: the data is being retreived
# --------------------------------------
#  324 hammerfest: the data is being retreived
# --------------------------------------
#  325 kalabo: the data is being retreived
# --------------------------------------
#  326 eenhana: the data is being retreived
# --------------------------------------
#  327 basoko: the data is being retreived
# --------------------------------------
#  328 davila: the data is being retreived
# --------------------------------------
#  329 pyaozerskiy: the data is being retreived
# --------------------------------------
#  330 sitka: the data is being retreived
# --------------------------------------
#  331 tsihombe: the data is being retreived
# Error missing city [tsihombe] in open weather api
# --------------------------------------
#  332 longyearbyen: the data is being retreived
# --------------------------------------
#  333 yerbogachen: the data is being retreived
# --------------------------------------
#  334 along: the data is being retreived
# --------------------------------------
#  335 babstovo: the data is being retreived
# --------------------------------------
#  336 ustye: the data is being retreived
# --------------------------------------
#  337 lazaro cardenas: the data is being retreived
# --------------------------------------
#  338 zainsk: the data is being retreived
# --------------------------------------
#  339 faya: the data is being retreived
# --------------------------------------
#  340 portobelo: the data is being retreived
# --------------------------------------
#  341 flinders: the data is being retreived
# --------------------------------------
#  342 mbandaka: the data is being retreived
# --------------------------------------
#  343 katsuura: the data is being retreived
# --------------------------------------
#  344 ketchikan: the data is being retreived
# --------------------------------------
#  345 new norfolk: the data is being retreived
# --------------------------------------
#  346 kununurra: the data is being retreived
# --------------------------------------
#  347 hay river: the data is being retreived
# --------------------------------------
#  348 dunedin: the data is being retreived
# --------------------------------------
#  349 general roca: the data is being retreived
# --------------------------------------
#  350 wana: the data is being retreived
# --------------------------------------
#  351 nipawin: the data is being retreived
# --------------------------------------
#  352 marcona: the data is being retreived
# Error missing city [marcona] in open weather api
# --------------------------------------
#  353 berlevag: the data is being retreived
# --------------------------------------
#  354 flores: the data is being retreived
# --------------------------------------
#  355 lysva: the data is being retreived
# --------------------------------------
#  356 okha: the data is being retreived
# --------------------------------------
#  357 viedma: the data is being retreived
# --------------------------------------
#  358 suamico: the data is being retreived
# --------------------------------------
#  359 jiwani: the data is being retreived
# --------------------------------------
#  360 dehloran: the data is being retreived
# --------------------------------------
#  361 saint george: the data is being retreived
# --------------------------------------
#  362 ugoofaaru: the data is being retreived
# --------------------------------------
#  363 srandakan: the data is being retreived
# --------------------------------------
#  364 gat: the data is being retreived
# --------------------------------------
#  365 shitanjing: the data is being retreived
# --------------------------------------
#  366 shimoda: the data is being retreived
# --------------------------------------
#  367 kahului: the data is being retreived
# --------------------------------------
#  368 pochutla: the data is being retreived
# --------------------------------------
#  369 hofn: the data is being retreived
# --------------------------------------
#  370 crab hill: the data is being retreived
# Error missing city [crab hill] in open weather api
# --------------------------------------
#  371 salinopolis: the data is being retreived
# --------------------------------------
#  372 west wendover: the data is being retreived
# --------------------------------------
#  373 laguna: the data is being retreived
# --------------------------------------
#  374 port-gentil: the data is being retreived
# --------------------------------------
#  375 hambantota: the data is being retreived
# --------------------------------------
#  376 kushmurun: the data is being retreived
# --------------------------------------
#  377 lolua: the data is being retreived
# Error missing city [lolua] in open weather api
# --------------------------------------
#  378 atambua: the data is being retreived
# --------------------------------------
#  379 ewa beach: the data is being retreived
# --------------------------------------
#  380 balkanabat: the data is being retreived
# --------------------------------------
#  381 caibiran: the data is being retreived
# --------------------------------------
#  382 banjar: the data is being retreived
# --------------------------------------
#  383 caborca: the data is being retreived
# --------------------------------------
#  384 bayonet point: the data is being retreived
# --------------------------------------
#  385 cazaje: the data is being retreived
# Error missing city [cazaje] in open weather api
# --------------------------------------
#  386 poum: the data is being retreived
# --------------------------------------
#  387 sola: the data is being retreived
# --------------------------------------
#  388 willowmore: the data is being retreived
# --------------------------------------
#  389 touros: the data is being retreived
# --------------------------------------
#  390 sechura: the data is being retreived
# --------------------------------------
#  391 coquimbo: the data is being retreived
# --------------------------------------
#  392 boende: the data is being retreived
# --------------------------------------
#  393 clyde river: the data is being retreived
# --------------------------------------
#  394 gao: the data is being retreived
# --------------------------------------
#  395 pozo colorado: the data is being retreived
# --------------------------------------
#  396 iskateley: the data is being retreived
# --------------------------------------
#  397 hervey bay: the data is being retreived
# --------------------------------------
#  398 alghero: the data is being retreived
# --------------------------------------
#  399 chuy: the data is being retreived
# --------------------------------------
#  400 nguiu: the data is being retreived
# Error missing city [nguiu] in open weather api
# --------------------------------------
#  401 bousso: the data is being retreived
# --------------------------------------
#  402 fort wellington: the data is being retreived
# --------------------------------------
#  403 correntina: the data is being retreived
# --------------------------------------
#  404 tambura: the data is being retreived
# --------------------------------------
#  405 sistranda: the data is being retreived
# --------------------------------------
#  406 russell: the data is being retreived
# --------------------------------------
#  407 graneros: the data is being retreived
# --------------------------------------
#  408 manggar: the data is being retreived
# --------------------------------------
#  409 meulaboh: the data is being retreived
# --------------------------------------
#  410 dharchula: the data is being retreived
# --------------------------------------
#  411 sompeta: the data is being retreived
# --------------------------------------
#  412 brownsville: the data is being retreived
# --------------------------------------
#  413 korla: the data is being retreived
# --------------------------------------
#  414 ortona: the data is being retreived
# --------------------------------------
#  415 colac: the data is being retreived
# --------------------------------------
#  416 karaul: the data is being retreived
# Error missing city [karaul] in open weather api
# --------------------------------------
#  417 yulara: the data is being retreived
# --------------------------------------
#  418 mercedes: the data is being retreived
# --------------------------------------
#  419 lensk: the data is being retreived
# --------------------------------------
#  420 panaba: the data is being retreived
# --------------------------------------
#  421 tyukalinsk: the data is being retreived
# --------------------------------------
#  422 krasnyy yar: the data is being retreived
# --------------------------------------
#  423 caranguejeira: the data is being retreived
# --------------------------------------
#  424 hakkari: the data is being retreived
# --------------------------------------
#  425 pasighat: the data is being retreived
# --------------------------------------
#  426 ostrovnoy: the data is being retreived
# --------------------------------------
#  427 vanavara: the data is being retreived
# --------------------------------------
#  428 alenquer: the data is being retreived
# --------------------------------------
#  429 isla mujeres: the data is being retreived
# --------------------------------------
#  430 kungur: the data is being retreived
# --------------------------------------
#  431 saint-pierre: the data is being retreived
# --------------------------------------
#  432 fier: the data is being retreived
# --------------------------------------
#  433 beringovskiy: the data is being retreived
# --------------------------------------
#  434 prescott: the data is being retreived
# --------------------------------------
#  435 ituni: the data is being retreived
# Error missing city [ituni] in open weather api
# --------------------------------------
#  436 gaya: the data is being retreived
# --------------------------------------
#  437 sinegorye: the data is being retreived
# --------------------------------------
#  438 bowen: the data is being retreived
# --------------------------------------
#  439 aflu: the data is being retreived
# Error missing city [aflu] in open weather api
# --------------------------------------
#  440 visby: the data is being retreived
# --------------------------------------
#  441 marsh harbour: the data is being retreived
# --------------------------------------
#  442 pisco: the data is being retreived
# --------------------------------------
#  443 pangnirtung: the data is being retreived
# --------------------------------------
#  444 kempele: the data is being retreived
# --------------------------------------
#  445 rovaniemi: the data is being retreived
# --------------------------------------
#  446 kabinda: the data is being retreived
# --------------------------------------
#  447 ixtapa: the data is being retreived
# --------------------------------------
#  448 bathsheba: the data is being retreived
# --------------------------------------
#  449 lorengau: the data is being retreived
# --------------------------------------
#  450 nouadhibou: the data is being retreived
# --------------------------------------
#  451 eureka: the data is being retreived
# --------------------------------------
#  452 zarand: the data is being retreived
# --------------------------------------
#  453 luceville: the data is being retreived
# Error missing city [luceville] in open weather api
# --------------------------------------
#  454 shelburne: the data is being retreived
# --------------------------------------
#  455 gurskoye: the data is being retreived
# Error missing city [gurskoye] in open weather api
# --------------------------------------
#  456 woodward: the data is being retreived
# --------------------------------------
#  457 walvis bay: the data is being retreived
# --------------------------------------
#  458 sakaiminato: the data is being retreived
# --------------------------------------
#  459 mana: the data is being retreived
# --------------------------------------
#  460 krasnoyarsk-45: the data is being retreived
# Error missing city [krasnoyarsk-45] in open weather api
# --------------------------------------
#  461 gerede: the data is being retreived
# --------------------------------------
#  462 maneadero: the data is being retreived
# --------------------------------------
#  463 bulgan: the data is being retreived
# --------------------------------------
#  464 ayagoz: the data is being retreived
# --------------------------------------
#  465 worcester: the data is being retreived
# --------------------------------------
#  466 palabuhanratu: the data is being retreived
# Error missing city [palabuhanratu] in open weather api
# --------------------------------------
#  467 bowmore: the data is being retreived
# --------------------------------------
#  468 kokuy: the data is being retreived
# --------------------------------------
#  469 cayenne: the data is being retreived
# --------------------------------------
#  470 anchorage: the data is being retreived
# --------------------------------------
#  471 vaitupu: the data is being retreived
# Error missing city [vaitupu] in open weather api
# --------------------------------------
#  472 arona: the data is being retreived
# --------------------------------------
#  473 porosozero: the data is being retreived
# --------------------------------------
#  474 kushiro: the data is being retreived
# --------------------------------------
#  475 fortuna: the data is being retreived
# --------------------------------------
#  476 herat: the data is being retreived
# --------------------------------------
#  477 sainte-marie: the data is being retreived
# --------------------------------------
#  478 victoria: the data is being retreived
# --------------------------------------
#  479 sehithwa: the data is being retreived
# --------------------------------------
#  480 voi: the data is being retreived
# --------------------------------------
#  481 gobabis: the data is being retreived
# --------------------------------------
#  482 fort saint james: the data is being retreived
# --------------------------------------
#  483 mbanza-ngungu: the data is being retreived
# --------------------------------------
#  484 quilali: the data is being retreived
# --------------------------------------
#  485 umm jarr: the data is being retreived
# Error missing city [umm jarr] in open weather api
# --------------------------------------
#  486 latung: the data is being retreived
# --------------------------------------
#  487 pallasovka: the data is being retreived
# --------------------------------------
#  488 payson: the data is being retreived
# --------------------------------------
#  489 mackay: the data is being retreived
# --------------------------------------
#  490 newport: the data is being retreived
# --------------------------------------
#  491 pangody: the data is being retreived
# --------------------------------------
#  492 namatanai: the data is being retreived
# --------------------------------------
#  493 kavaratti: the data is being retreived
# --------------------------------------
#  494 mvuma: the data is being retreived
# --------------------------------------
#  495 tyumentsevo: the data is being retreived
# --------------------------------------
#  496 mnogovershinnyy: the data is being retreived
# --------------------------------------
#  497 coihaique: the data is being retreived
# --------------------------------------
#  498 alexandria: the data is being retreived
# --------------------------------------
#  499 najran: the data is being retreived
# --------------------------------------
#  500 pontianak: the data is being retreived
# --------------------------------------
#  501 namibe: the data is being retreived
# --------------------------------------
#  502 ailigandi: the data is being retreived
# --------------------------------------
#  503 quatre cocos: the data is being retreived
# --------------------------------------
#  504 weligama: the data is being retreived
# --------------------------------------
#  505 victor harbor: the data is being retreived
# --------------------------------------
#  506 mango: the data is being retreived
# --------------------------------------
#  507 talnakh: the data is being retreived
# --------------------------------------
#  508 port hardy: the data is being retreived
# --------------------------------------
#  509 riverton: the data is being retreived
# --------------------------------------
#  510 asfi: the data is being retreived
# --------------------------------------
#  511 raudeberg: the data is being retreived
# --------------------------------------
#  512 rincon: the data is being retreived
# --------------------------------------
#  513 miami: the data is being retreived
# --------------------------------------
#  514 lata: the data is being retreived
# --------------------------------------
#  515 xining: the data is being retreived
# --------------------------------------
#  516 agadez: the data is being retreived
# --------------------------------------
#  517 klaksvik: the data is being retreived
# --------------------------------------
#  518 portland: the data is being retreived
# --------------------------------------
#  519 lobito: the data is being retreived
# --------------------------------------
#  520 azimur: the data is being retreived
# Error missing city [azimur] in open weather api
# --------------------------------------
#  521 chauk: the data is being retreived
# --------------------------------------
#  522 borzya: the data is being retreived
# --------------------------------------
#  523 ngukurr: the data is being retreived
# Error missing city [ngukurr] in open weather api
# --------------------------------------
#  524 samalaeulu: the data is being retreived
# Error missing city [samalaeulu] in open weather api
# --------------------------------------
#  525 santa maria: the data is being retreived
# --------------------------------------
#  526 liverpool: the data is being retreived
# --------------------------------------
#  527 teberda: the data is being retreived
# --------------------------------------
#  528 wukari: the data is being retreived
# --------------------------------------
#  529 waipawa: the data is being retreived
# --------------------------------------
#  530 lokken verk: the data is being retreived
# Error missing city [lokken verk] in open weather api
# --------------------------------------
#  531 lavrentiya: the data is being retreived
# --------------------------------------
#  532 mouzakion: the data is being retreived
# Error missing city [mouzakion] in open weather api
# --------------------------------------
#  533 almeria: the data is being retreived
# --------------------------------------
#  534 corn island: the data is being retreived
# --------------------------------------
#  535 lagoa: the data is being retreived
# --------------------------------------
#  536 north bend: the data is being retreived
# --------------------------------------
#  537 anjozorobe: the data is being retreived
# --------------------------------------
#  538 jiaocheng: the data is being retreived
# --------------------------------------
#  539 guerrero negro: the data is being retreived
# --------------------------------------
#  540 chicama: the data is being retreived
# --------------------------------------
#  541 kismayo: the data is being retreived
# --------------------------------------
#  542 anloga: the data is being retreived
# --------------------------------------
#  543 muzhi: the data is being retreived
# --------------------------------------
#  544 lufilufi: the data is being retreived
# --------------------------------------
#  545 khasan: the data is being retreived
# --------------------------------------
#  546 nortelandia: the data is being retreived
# --------------------------------------
#  547 port moresby: the data is being retreived
# --------------------------------------
#  548 shaowu: the data is being retreived
# --------------------------------------
#  549 umm durman: the data is being retreived
# Error missing city [umm durman] in open weather api
# --------------------------------------
#  550 elizabeth city: the data is being retreived
# --------------------------------------
#  551 lady frere: the data is being retreived
# --------------------------------------
#  552 lappeenranta: the data is being retreived
# --------------------------------------
#  553 kwinana: the data is being retreived
# --------------------------------------
#  554 ligatne: the data is being retreived
# --------------------------------------
#  555 gornopravdinsk: the data is being retreived
# --------------------------------------
#  556 svolvaer: the data is being retreived
# --------------------------------------
#  557 ishigaki: the data is being retreived
# --------------------------------------
#  558 mujiayingzi: the data is being retreived
# --------------------------------------
#  559 plettenberg bay: the data is being retreived
# --------------------------------------
#  560 nueve de julio: the data is being retreived
# --------------------------------------
#  561 honningsvag: the data is being retreived
# --------------------------------------
#  562 avera: the data is being retreived
# --------------------------------------
#  563 yurga: the data is being retreived
# --------------------------------------
#  564 nuuk: the data is being retreived
# --------------------------------------
#  565 sioux lookout: the data is being retreived
# --------------------------------------
#  566 dzhebariki-khaya: the data is being retreived
# --------------------------------------
#  567 necochea: the data is being retreived
# --------------------------------------
#  568 ormara: the data is being retreived
# --------------------------------------
#  569 paramonga: the data is being retreived
# --------------------------------------
#  570 mongoumba: the data is being retreived
# --------------------------------------
#  571 troitskoye: the data is being retreived
# --------------------------------------
#  572 poronaysk: the data is being retreived
# --------------------------------------
#  573 shetpe: the data is being retreived
# --------------------------------------
#  574 milingimbi: the data is being retreived
# Error missing city [milingimbi] in open weather api
# --------------------------------------
#  575 moose factory: the data is being retreived
# --------------------------------------
#  576 visconde do rio branco: the data is being retreived
# --------------------------------------
#  577 saint-michel-des-saints: the data is being retreived
# --------------------------------------
#  578 lovington: the data is being retreived
# --------------------------------------
#  579 caarapo: the data is being retreived
# --------------------------------------
#  580 igarape-miri: the data is being retreived
# Error missing city [igarape-miri] in open weather api
# --------------------------------------
#  581 bandarbeyla: the data is being retreived
# --------------------------------------
#  582 pitimbu: the data is being retreived
# --------------------------------------
#  583 kulotino: the data is being retreived
# --------------------------------------
#  584 isla vista: the data is being retreived
# --------------------------------------
#  585 nigran: the data is being retreived
# --------------------------------------
#  586 cabedelo: the data is being retreived
# --------------------------------------
#  587 daye: the data is being retreived
# --------------------------------------
#  588 piney green: the data is being retreived
# --------------------------------------
#  589 lakatoro: the data is being retreived
# --------------------------------------
#  590 calama: the data is being retreived

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df.head()
# Out:
#             City Latitude Longitude Max Temp (F) Humidity (%) Cloudiness (%)  \
# 0       acapulco    16.86    -99.89         89.6           66             75
# 1        kurilsk    45.23    147.88        47.21           91             93
# 2      sinnamary     5.38    -52.95        79.34           89            100
# 3         faanui   -16.48   -151.75        78.89           78             39
# 4  leningradskiy    69.38    178.42       32.324           96            100
#
#   Wind Speed (mph) Country        Date
# 0              3.6      MX  06/23/2020
# 1             2.73      RU  06/23/2020
# 2             4.78      GF  06/23/2020
# 3             7.71      PF  06/23/2020
# 4              6.2      RU  06/23/2020

# %%
#delete rows with empty cells from the dataframe

nan_value = float("NaN")
weather_df.replace("",nan_value, inplace=True)
weather_df.dropna(subset=["Latitude"],inplace=True)
weather_df
# Out:
#               City  Latitude  Longitude  Max Temp (F)  Humidity (%)  \
# 0         acapulco     16.86     -99.89        89.600          66.0
# 1          kurilsk     45.23     147.88        47.210          91.0
# 2        sinnamary      5.38     -52.95        79.340          89.0
# 3           faanui    -16.48    -151.75        78.890          78.0
# 4    leningradskiy     69.38     178.42        32.324          96.0
# ..             ...       ...        ...           ...           ...
# 586       cabedelo     -6.98     -34.83        84.200          62.0
# 587           daye     30.08     114.95        74.462          91.0
# 588    piney green     34.72     -77.32        91.004          55.0
# 589       lakatoro    -16.10     167.42        73.400         100.0
# 590         calama    -22.47     -68.93        68.000           9.0
#
#      Cloudiness (%)  Wind Speed (mph) Country        Date
# 0              75.0              3.60      MX  06/23/2020
# 1              93.0              2.73      RU  06/23/2020
# 2             100.0              4.78      GF  06/23/2020
# 3              39.0              7.71      PF  06/23/2020
# 4             100.0              6.20      RU  06/23/2020
# ..              ...               ...     ...         ...
# 586            20.0              6.70      BR  06/23/2020
# 587           100.0              1.55      CN  06/23/2020
# 588            75.0              3.60      US  06/23/2020
# 589            40.0              2.78      VU  06/23/2020
# 590             0.0              9.30      CL  06/23/2020
#
# [536 rows x 9 columns]

# %%
#export weather_df to cities.csv

weather_df.to_csv("../output_data/cities.csv")

# %%
#Checking the number of rows per colums
print(f"Latitud column has {len(weather_df['Latitude'])} rows")
print(f"Longitude column has {len(weather_df['Longitude'])} rows")
print(f"Max Temp column has {len(weather_df['Max Temp (F)'])} rows")
print(f"Humidity column has {len(weather_df['Humidity (%)'])} rows")
print(f"Cloudiness column has {len(weather_df['Cloudiness (%)'])} rows")
print(f"Wind Speed column has {len(weather_df['Wind Speed (mph)'])} rows")
print(f"Country column has {len(weather_df['Country'])} rows")
print(f"Date column has {len(weather_df['Date'])} rows")
# Out:
# Latitud column has 536 rows
# Longitude column has 536 rows
# Max Temp column has 536 rows
# Humidity column has 536 rows
# Cloudiness column has 536 rows
# Wind Speed column has 536 rows
# Country column has 536 rows
# Date column has 536 rows

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#create a new dataframe excluding cities with Humidity greater than 100
clean_city_data=weather_df[weather_df["Humidity (%)"]<=100]
clean_city_data
# Out:
#               City  Latitude  Longitude  Max Temp (F)  Humidity (%)  \
# 0         acapulco     16.86     -99.89        89.600          66.0
# 1          kurilsk     45.23     147.88        47.210          91.0
# 2        sinnamary      5.38     -52.95        79.340          89.0
# 3           faanui    -16.48    -151.75        78.890          78.0
# 4    leningradskiy     69.38     178.42        32.324          96.0
# ..             ...       ...        ...           ...           ...
# 586       cabedelo     -6.98     -34.83        84.200          62.0
# 587           daye     30.08     114.95        74.462          91.0
# 588    piney green     34.72     -77.32        91.004          55.0
# 589       lakatoro    -16.10     167.42        73.400         100.0
# 590         calama    -22.47     -68.93        68.000           9.0
#
#      Cloudiness (%)  Wind Speed (mph) Country        Date
# 0              75.0              3.60      MX  06/23/2020
# 1              93.0              2.73      RU  06/23/2020
# 2             100.0              4.78      GF  06/23/2020
# 3              39.0              7.71      PF  06/23/2020
# 4             100.0              6.20      RU  06/23/2020
# ..              ...               ...     ...         ...
# 586            20.0              6.70      BR  06/23/2020
# 587           100.0              1.55      CN  06/23/2020
# 588            75.0              3.60      US  06/23/2020
# 589            40.0              2.78      VU  06/23/2020
# 590             0.0              9.30      CL  06/23/2020
#
# [536 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
latitude=weather_df.loc[:,"Latitude"]
temperature=weather_df.loc[:,"Max Temp (F)"]
latitude_temperature=(pd.DataFrame({"Latitude":latitude,"Max Temp (F)":temperature}))
latitude_temperature.plot(kind="scatter",x="Latitude", y="Max Temp (F)", c="r", alpha=0.5)
plt.title(f"Latitude vs. Max Temp (F) ({clean_city_data['Date'][0]})")
plt.xlim(min(clean_city_data["Latitude"])-10,max(clean_city_data["Latitude"])+10)
plt.ylim(min(clean_city_data["Max Temp (F)"])-5,max(clean_city_data["Max Temp (F)"])+5)
plt.grid()
plt.savefig("../output_data/Fig1.png")
plt.show()


print(f"Correlation between Latitud and Maximum Temperature \nThe closer the city is to latitud 20, the higher the temperature")
# Out:
# Correlation between Latitud and Maximum Temperature
# The closer the city is to latitud 20, the higher the temperature

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
latitude=weather_df.loc[:,"Latitude"]
humidity=weather_df.loc[:,"Humidity (%)"]
latitude_humidity=(pd.DataFrame({"Latitude":latitude,"Humidity (%)":humidity}))
latitude_humidity.plot(kind="scatter",x="Latitude", y="Humidity (%)", c="r", alpha=0.5)
plt.title(f"Latitude vs. Humidity (%) ({clean_city_data['Date'][0]})")
plt.xlim(min(clean_city_data["Latitude"])-10,max(clean_city_data["Latitude"])+10)
plt.ylim(min(clean_city_data["Humidity (%)"])-5,max(clean_city_data["Humidity (%)"])+5)
plt.grid()
plt.savefig("../output_data/Fig2.png")
plt.show()

print("Correlation between Latitud and Huidity \nThere is no clear correlation between Latitud and Huidity, the Humidity doesn't have dependency on the Latitud")
# Out:
# Correlation between Latitud and Huidity
# There is no clear correlation between Latitud and Huidity, the Humidity doesn't have dependency on the Latitud

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
latitude=weather_df.loc[:,"Latitude"]
cloudiness=weather_df.loc[:,"Cloudiness (%)"]
latitude_cloudiness=(pd.DataFrame({"Latitude":latitude,"Cloudiness (%)":cloudiness}))
latitude_cloudiness.plot(kind="scatter",x="Latitude", y="Cloudiness (%)", c="r", alpha=0.5)
plt.title(f"Latitude vs. Cloudiness (%) ({clean_city_data['Date'][0]})")
plt.xlim(min(clean_city_data["Latitude"])-10,max(clean_city_data["Latitude"])+10)
plt.ylim(min(clean_city_data["Cloudiness (%)"])-5,max(clean_city_data["Cloudiness (%)"])+5)
plt.grid()
plt.savefig("../output_data/Fig3.png")
plt.show()

print("Correlation between Latitud and Cloudiness \nThere is no clear correlation between Latitud and Clousiness, the Cloudiness doesn't have dependency on the Latitud")
# Out:
# Correlation between Latitud and Cloudiness
# There is no clear correlation between Latitud and Clousiness, the Cloudiness doesn't have dependency on the Latitud

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
latitude=weather_df.loc[:,"Latitude"]
wind=weather_df.loc[:,"Wind Speed (mph)"]
latitude_wind=(pd.DataFrame({"Latitude":latitude,"Wind Speed (mph)":wind}))
latitude_wind.plot(kind="scatter",x="Latitude", y="Wind Speed (mph)", c="r", alpha=0.5)
plt.title("Latitude vs. Wind Speed (mph)")
plt.xlim(min(clean_city_data["Latitude"])-10,max(clean_city_data["Latitude"])+10)
plt.ylim(min(clean_city_data["Wind Speed (mph)"])-1,max(clean_city_data["Wind Speed (mph)"])+1)
plt.grid()
plt.savefig("../output_data/Fig4.png")
plt.show()

print("Correlation between Latitud and Wind Speed \nThere is no clear correlation between Latitud and Wind Speed, the Wind Speed doesn't have dependency on the Latitud")
# Out:
# Correlation between Latitud and Wind Speed
# There is no clear correlation between Latitud and Wind Speed, the Wind Speed doesn't have dependency on the Latitud

# %% [markdown]
# ## Linear Regression

# %%
#create a dictionary
dic = {}
dic["latitude_temperature_northern"]=latitude_temperature[latitude_temperature["Latitude"]>=0]
dic["latitude_temperature_southern"]=latitude_temperature[latitude_temperature["Latitude"]<0]
dic["latitude_humidity_northern"]=latitude_humidity[latitude_humidity["Latitude"]>=0]
dic["latitude_humidity_southern"]=latitude_humidity[latitude_humidity["Latitude"]<0]
dic["latitude_cloudiness_northern"]=latitude_cloudiness[latitude_cloudiness["Latitude"]>=0]
dic["latitude_cloudiness_southern"]=latitude_cloudiness[latitude_cloudiness["Latitude"]<0]
dic["latitude_wind_northern"]=latitude_wind[latitude_wind["Latitude"]>=0]
dic["latitude_wind_southern"]=latitude_wind[latitude_wind["Latitude"]<0]

# %%
#function to creater scaterplots and regression lines for different value in dictionary above
def scatter_plot(hemisphere,y_value,column):

    if hemisphere == "northern":
        original_df = dic[f"latitude_{y_value}_northern"]
        
        data_frame = original_df[original_df["Latitude"]>=0]
        data_frame.plot(kind="scatter",x="Latitude",y=column, c="g", alpha=0.5)
        plt.title(f"Northern Hemisphere Latitude vs. {column}")
        
        x_values = original_df["Latitude"]
        y_values = original_df[column]
    
        (slope, intercept, rvalue, pvalue,stderr) = linregress(x_values,y_values)
    
        regress_value = x_values*slope+intercept
        line_eq = "y="+str(round(slope,2))+"x+"+str(round(intercept,2))
        print(f"The Least Squares Regression Line is: {line_eq}")
        print(f"The correlation is {x_values.corr(y_values)}")
        print(f"The r-squared is: {rvalue**2}")
        plt.plot(x_values,regress_value,"r-")
        plt.annotate(line_eq,(min(x_values),min(y_values)), fontsize=14, color="red")
        
        plt.grid()
        plt.show()
        
    elif hemisphere == "southern":
        original_df = dic[f"latitude_{y_value}_southern"]
        
        data_frame = original_df[original_df["Latitude"]<0]
        data_frame.plot(kind="scatter",x="Latitude",y=column, c="g", alpha=0.5)
        plt.title(f"Southern Hemisphere Latitude vs. {column}")
        
        x_values = original_df["Latitude"]
        y_values = original_df[column]
    
        (slope, intercept, rvalue, pvalue,stderr) = linregress(x_values,y_values)
    
        regress_value = x_values*slope+intercept
        line_eq = "y="+str(round(slope,2))+"x+"+str(round(intercept,2))
        print(f"The Least Squares Regression Line is: {line_eq}")
        print(f"The correlation is {x_values.corr(y_values)}")
        print(f"The r-squared is: {rvalue**2}")
        plt.plot(x_values,regress_value,"r-")
        plt.annotate(line_eq,(min(x_values),min(y_values)), fontsize=14, color="red")
        
        plt.grid()
        plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
scatter_plot("northern","temperature","Max Temp (F)")
# Out:
# The Least Squares Regression Line is: y=-0.57x+92.42
# The correlation is -0.7391636321818154

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
scatter_plot("southern","temperature","Max Temp (F)")
# Out:
# The Least Squares Regression Line is: y=0.79x+83.3
# The correlation is 0.7832765704433573

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
scatter_plot("northern","humidity","Humidity (%)")
# Out:
# The Least Squares Regression Line is: y=0.06x+64.54
# The correlation is 0.05741846182369083

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
scatter_plot("southern","humidity","Humidity (%)")
# Out:
# The Least Squares Regression Line is: y=-0.16x+69.55
# The correlation is -0.11756801332911454

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
scatter_plot("northern","cloudiness","Cloudiness (%)")
# Out:
# The Least Squares Regression Line is: y=-0.12x+53.94
# The correlation is -0.06232460230594995

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
scatter_plot("southern","cloudiness","Cloudiness (%)")
# Out:
# The Least Squares Regression Line is: y=0.38x+48.13
# The correlation is 0.13418395115213008

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
scatter_plot("northern","wind","Wind Speed (mph)")
# Out:
# The Least Squares Regression Line is: y=-0.0x+3.71

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
scatter_plot("southern","wind","Wind Speed (mph)")
# Out:
# The Least Squares Regression Line is: y=-0.02x+2.99
